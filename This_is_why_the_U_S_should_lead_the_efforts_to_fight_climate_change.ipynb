# %%
import pandas as pd

url="https://bd29ee0e-54ab-4daa-9671-d153865d1620.usrfiles.com/ugd/bd29ee_1ff034cd9d5243feb7ffb3923815a393.csv"
df=pd.read_csv(url)
df.head()
# Out:
#    COU    Country  POL  ...       Value Flag Codes Flags
# 0  AUS  Australia  GHG  ...  424998.381        NaN   NaN
# 1  AUS  Australia  GHG  ...  426015.210        NaN   NaN
# 2  AUS  Australia  GHG  ...  430216.380        NaN   NaN
# 3  AUS  Australia  GHG  ...  430612.556        NaN   NaN
# 4  AUS  Australia  GHG  ...  430653.332        NaN   NaN
#
# [5 rows x 17 columns]

# %% [markdown]
# ###### Let's get to know the dataset first.

# %%
import numpy as np

np.unique(df["Country"])
# Out:
# array(['Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Canada',
#        'Chile', "China (People's Republic of)", 'Colombia', 'Costa Rica',
#        'Czech Republic', 'Denmark', 'Estonia',
#        'European Union (28 countries)', 'Finland', 'France', 'Germany',
#        'Greece', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Ireland',
#        'Israel', 'Italy', 'Japan', 'Korea', 'Latvia', 'Lithuania',
#        'Luxembourg', 'Mexico', 'Netherlands', 'New Zealand', 'Norway',
#        'OECD - Europe', 'OECD - Total', 'Poland', 'Portugal', 'Russia',
#        'Slovak Republic', 'Slovenia', 'South Africa', 'Spain', 'Sweden',
#        'Switzerland', 'Turkey', 'United Kingdom', 'United States'],
#       dtype=object)

# %%
# Drop the rows for "European Union", "OECD - Europe" and "OECD - Total" to avoid double-counting. 
# If we include these organizations and the individual memeber countries, that will be double-counting.
df=df.drop(df[df["Country"]=='European Union (28 countries)'].index)
df=df.drop(df[df["Country"]=='OECD - Europe'].index)
df=df.drop(df[df["Country"]=='OECD - Total'].index)
# Verify that those summary rows had been dropped.
np.unique(df["Country"])
# Out:
# array(['Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Canada',
#        'Chile', "China (People's Republic of)", 'Colombia', 'Costa Rica',
#        'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Ireland', 'Israel', 'Italy', 'Japan', 'Korea', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Mexico', 'Netherlands', 'New Zealand',
#        'Norway', 'Poland', 'Portugal', 'Russia', 'Slovak Republic',
#        'Slovenia', 'South Africa', 'Spain', 'Sweden', 'Switzerland',
#        'Turkey', 'United Kingdom', 'United States'], dtype=object)

# %%
# Let's see what is in the "Pollutant" column.
np.unique(df["Pollutant"])
# Out:
# array(['Carbon dioxide', 'Greenhouse gases', 'Hydrofluorocarbons',
#        'Methane', 'Nitrogen trifluoride', 'Nitrous oxide',
#        'Perfluorocarbons', 'Sulphur hexafluoride',
#        'Unspecified mix of HFCs and PFCs'], dtype=object)

# %% [markdown]
# ###### The "Pollutant" column includes rows for "Greenhouse gases" (the overall name) as well as rows for each gas. I want to analyze emission of all the greenhouse gases by countries. Hence, I want the rows for "Greenhouse gases" (the overall name), not the specific gas.

# %%
df=df[df["Pollutant"]=='Greenhouse gases']
np.unique(df["Pollutant"])
# Out:
# array(['Greenhouse gases'], dtype=object)

# %%
# Let's see what is in the "VAR" column.
np.unique(df["VAR"])
# Out:
# array(['AFOLU', 'AGR', 'AGR_P', 'ENER', 'ENER_CO2', 'ENER_CO2_P',
#        'ENER_FU', 'ENER_FU_P', 'ENER_IND', 'ENER_IND_P', 'ENER_MANUF',
#        'ENER_MANUF_P', 'ENER_OSECT', 'ENER_OSECT_P', 'ENER_OTH',
#        'ENER_OTH_P', 'ENER_P', 'ENER_TRANS', 'ENER_TRANS_P', 'GHG_CAP',
#        'GHG_GDP', 'INDEX_1990', 'INDEX_2000', 'IND_PROC', 'IND_PROC_P',
#        'LULUCF', 'OTH', 'OTH_P', 'TOTAL', 'TOTAL_LULU', 'WAS', 'WAS_P'],
#       dtype=object)

# %% [markdown]
# ##### Since I want to analyze total greenhouse gases emission, I want the "TOTAL" rows only.

# %%
df=df[df["VAR"]=="TOTAL"]
np.unique(df["VAR"])
# Out:
# array(['TOTAL'], dtype=object)

# %%
# Let's see what is in the "Variable" column.
np.unique(df["Variable"])
# Out:
# array(['Total  emissions excluding LULUCF'], dtype=object)

# %% [markdown]
# ###### I have dropped all the rows that I don't need.

# %%
# Let's output the column names.
df.columns
# Out:
# Index(['COU', 'Country', 'POL', 'Pollutant', 'VAR', 'Variable', 'YEA', 'Year',
#        'Unit Code', 'Unit', 'PowerCode Code', 'PowerCode',
#        'Reference Period Code', 'Reference Period', 'Value', 'Flag Codes',
#        'Flags'],
#       dtype='object')

# %% [markdown]
# ##### For the analysis I want to perform, I only need the "COU" column, which consists of the three-alphabet country codes, the "Country" column, which has the country names, the "Value" column, which consists of the total greenhouse gases emission for the countries and the "Year" column.

# %%
df=df[["COU","Country","Value","Year"]]
df.columns
# Out:
# Index(['COU', 'Country', 'Value', 'Year'], dtype='object')

# %% [markdown]
# ###### An animated map to visualize the analytical results as a time series.

# %%
import plotly.express as px

fig = px.choropleth(df,
                    locations ="COU",
                    color ="Value",
                    hover_name ="Country", 
                    color_continuous_scale = px.colors.sequential.Plasma,
                    scope ="world",
                    labels={'Value':'Greenhouse gases in millions of metric tons'},
                    animation_frame ="Year")
fig.update_layout(title="Greenhouse gases emission by country, 1990-2018")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="49a42327-be1c-4148-893b-d469b6fc7460" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("49a42327-be1c-4148-893b-d469b6fc7460")) {
#                     Plotly.newPlot(
#                         '49a42327-be1c-4148-893b-d469b6fc7460',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Year=1990<br>COU=%{location}<br>Greenhouse gases in millions of metric tons=%{z}", "hovertext": ["Australia", "Austria", "Belgium", "Canada", "Czech Republic", "Denmark", "Finland", "France", "Germany", "Greece", "Hungary", "Iceland", "Ireland", "Italy", "Japan", "Korea", "Luxembourg", "Mexico", "Netherlands", "New Zealand", "Norway", "Poland", "Portugal", "Slovak Republic", "Spain", "Sweden", "Switzerland", "Turkey", "United Kingdom", "United States", "Chile", "Estonia", "Russia", "Slovenia", "Lithuania", "Latvia", "Brazil", "Colombia", "South Africa", "Argentina"], "locations": ["AUS", "AUT", "BEL", "CAN", "CZE", "DNK", "FIN", "FRA", "DEU", "GRC", "HUN", "ISL", "IRL", "ITA", "JPN", "KOR", "LUX", "MEX", "NLD", "NZL", "NOR", "POL", "PRT", "SVK", "ESP", "SWE", "CHE", "TUR", "GBR", "USA", "CHL", "EST", "RUS", "SVN", "LTU", "LVA", "BRA", "COL", "ZAF", "ARG"], "name": "", "type": "choropleth", "z": [424998.381, 78492.61200000001, 146410.75699999998, 603221.8670000001, 197202.548, 71000.02, 71065.26400000001, 551404.7779999999, 1249458.562, 103308.905, 93950.883, 3732.8720000000003, 55468.295999999995, 516051.742, 1270039.967, 292939.0, 12741.063999999998, 444741.575, 220740.867, 63590.927, 51459.02099999999, 475080.316, 58558.607, 73517.128, 289383.32899999997, 71184.925, 53778.897000000004, 219367.813, 797812.0440000001, 6437000.131, 52015.932, 40277.309, 3187507.079, 18609.592, 48016.431, 26288.572999999997, 573078.754, 94040.615, 347349.4, 220240.771]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "Greenhouse gases in millions of metric tons"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "scope": "world"}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "Year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1990"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1990", "method": "animate"}, {"args": [["1991"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1991", "method": "animate"}, {"args": [["1992"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1992", "method": "animate"}, {"args": [["1993"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1993", "method": "animate"}, {"args": [["1994"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1994", "method": "animate"}, {"args": [["1995"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1995", "method": "animate"}, {"args": [["1996"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1996", "method": "animate"}, {"args": [["1997"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1997", "method": "animate"}, {"args": [["1998"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1998", "method": "animate"}, {"args": [["1999"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1999", "method": "animate"}, {"args": [["2000"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2000", "method": "animate"}, {"args": [["2001"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2001", "method": "animate"}, {"args": [["2002"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2002", "method": "animate"}, {"args": [["2003"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2003", "method": "animate"}, {"args": [["2004"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2004", "method": "animate"}, {"args": [["2005"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2005", "method": "animate"}, {"args": [["2006"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "l ...

# %%
# Define a function to rank the countries based on the percentage of greenhouse gases emission.
def ghg_rank(n):
  yearn=df[df["Year"]==n]
  "Group the data by year, calcualte each country's contribution to global ghg each year, then rank them based on the % of global ghg that they contributed."
  year_sums = yearn.groupby(['Year',"Country"]).agg({'Value': 'sum'})
  year_sums = year_sums.groupby(level=0).apply(lambda x:
                                                 100 * x / float(x.sum())).rename(columns={"Value":"Greenhouse gases emission(%)"}).reset_index()
  comparison=year_sums.sort_values(by=["Greenhouse gases emission(%)"],ascending=False)
  fig = px.bar(comparison, x="Country", y="Greenhouse gases emission(%)",
             color='Country',
             height=400)
  fig.update_layout(title=f"Greenhouse gases emission by country, {n}")
  return fig.show()

# %% [markdown]
# ###### Static bar charts to visualize the analytical results year by year.

# %%
# Use a loop for go through all the years for which data were available. 
for i in np.arange(1990,2019):
  ghg_rank(i)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a77af461-9e24-478e-abbc-f252b4679a1d" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a77af461-9e24-478e-abbc-f252b4679a1d")) {
#                     Plotly.newPlot(
#                         'a77af461-9e24-478e-abbc-f252b4679a1d',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United States", "marker": {"color": "#636efa"}, "name": "Country=United States", "offsetgroup": "Country=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [32.833247900428326], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Russia", "marker": {"color": "#EF553B"}, "name": "Country=Russia", "offsetgroup": "Country=Russia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Russia"], "xaxis": "x", "y": [16.258537824966396], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Japan", "marker": {"color": "#00cc96"}, "name": "Country=Japan", "offsetgroup": "Country=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Japan"], "xaxis": "x", "y": [6.478101014654586], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Germany", "marker": {"color": "#ab63fa"}, "name": "Country=Germany", "offsetgroup": "Country=Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Germany"], "xaxis": "x", "y": [6.373121310017057], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United Kingdom", "marker": {"color": "#FFA15A"}, "name": "Country=United Kingdom", "offsetgroup": "Country=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [4.0694050156140085], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Canada", "marker": {"color": "#19d3f3"}, "name": "Country=Canada", "offsetgroup": "Country=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Canada"], "xaxis": "x", "y": [3.0768576503187592], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Brazil", "marker": {"color": "#FF6692"}, "name": "Country=Brazil", "offsetgroup": "Country=Brazil", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Brazil"], "xaxis": "x", "y": [2.9231064802895186], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=France", "marker": {"color": "#B6E880"}, "name": "Country=France", "offsetgroup": "Country=France", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["France"], "xaxis": "x", "y": [2.812553891736847], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Italy", "marker": {"color": "#FF97FF"}, "name": "Country=Italy", "offsetgroup": "Country=Italy", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Italy"], "xaxis": "x", "y": [2.632228434008382], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Poland", "marker": {"color": "#FECB52"}, "name": "Country=Poland", "offsetgroup": "Country=Poland", "orientation":  ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b14ffda7-9fcc-4abf-a53b-28e210b4e668" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b14ffda7-9fcc-4abf-a53b-28e210b4e668")) {
#                     Plotly.newPlot(
#                         'b14ffda7-9fcc-4abf-a53b-28e210b4e668',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United States", "marker": {"color": "#636efa"}, "name": "Country=United States", "offsetgroup": "Country=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [33.39864099213726], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Russia", "marker": {"color": "#EF553B"}, "name": "Country=Russia", "offsetgroup": "Country=Russia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Russia"], "xaxis": "x", "y": [15.8517207884186], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Japan", "marker": {"color": "#00cc96"}, "name": "Country=Japan", "offsetgroup": "Country=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Japan"], "xaxis": "x", "y": [6.728722246155846], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Germany", "marker": {"color": "#ab63fa"}, "name": "Country=Germany", "offsetgroup": "Country=Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Germany"], "xaxis": "x", "y": [6.301141177491643], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United Kingdom", "marker": {"color": "#FFA15A"}, "name": "Country=United Kingdom", "offsetgroup": "Country=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [4.230266722053251], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Canada", "marker": {"color": "#19d3f3"}, "name": "Country=Canada", "offsetgroup": "Country=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Canada"], "xaxis": "x", "y": [3.117392054867615], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Brazil", "marker": {"color": "#FF6692"}, "name": "Country=Brazil", "offsetgroup": "Country=Brazil", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Brazil"], "xaxis": "x", "y": [3.103091143564026], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=France", "marker": {"color": "#B6E880"}, "name": "Country=France", "offsetgroup": "Country=France", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["France"], "xaxis": "x", "y": [3.032635873721795], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Italy", "marker": {"color": "#FF97FF"}, "name": "Country=Italy", "offsetgroup": "Country=Italy", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Italy"], "xaxis": "x", "y": [2.709864635327848], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Poland", "marker": {"color": "#FECB52"}, "name": "Country=Poland", "offsetgroup": "Country=Poland", "orientation": "v", " ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2c6950b7-f61c-49b9-ad87-6c01ad7269c4" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2c6950b7-f61c-49b9-ad87-6c01ad7269c4")) {
#                     Plotly.newPlot(
#                         '2c6950b7-f61c-49b9-ad87-6c01ad7269c4',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United States", "marker": {"color": "#636efa"}, "name": "Country=United States", "offsetgroup": "Country=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [34.76726451592193], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Russia", "marker": {"color": "#EF553B"}, "name": "Country=Russia", "offsetgroup": "Country=Russia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Russia"], "xaxis": "x", "y": [13.614347057425388], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Japan", "marker": {"color": "#00cc96"}, "name": "Country=Japan", "offsetgroup": "Country=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Japan"], "xaxis": "x", "y": [6.956925293127953], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Germany", "marker": {"color": "#ab63fa"}, "name": "Country=Germany", "offsetgroup": "Country=Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Germany"], "xaxis": "x", "y": [6.182015176535285], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United Kingdom", "marker": {"color": "#FFA15A"}, "name": "Country=United Kingdom", "offsetgroup": "Country=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [4.219422811317643], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Canada", "marker": {"color": "#19d3f3"}, "name": "Country=Canada", "offsetgroup": "Country=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Canada"], "xaxis": "x", "y": [3.2860555033380283], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Brazil", "marker": {"color": "#FF6692"}, "name": "Country=Brazil", "offsetgroup": "Country=Brazil", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Brazil"], "xaxis": "x", "y": [3.227917408873374], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=France", "marker": {"color": "#B6E880"}, "name": "Country=France", "offsetgroup": "Country=France", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["France"], "xaxis": "x", "y": [3.0416948555040113], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Italy", "marker": {"color": "#FF97FF"}, "name": "Country=Italy", "offsetgroup": "Country=Italy", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Italy"], "xaxis": "x", "y": [2.7690967790733203], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Mexico", "marker": {"color": "#FECB52"}, "name": "Country=Mexico", "offsetgroup": "Country=Mexico", "orientation": " ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7c189e4f-708c-449e-bb5b-d9148a506022" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7c189e4f-708c-449e-bb5b-d9148a506022")) {
#                     Plotly.newPlot(
#                         '7c189e4f-708c-449e-bb5b-d9148a506022',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United States", "marker": {"color": "#636efa"}, "name": "Country=United States", "offsetgroup": "Country=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [35.48458547611955], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Russia", "marker": {"color": "#EF553B"}, "name": "Country=Russia", "offsetgroup": "Country=Russia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Russia"], "xaxis": "x", "y": [12.90824277113027], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Japan", "marker": {"color": "#00cc96"}, "name": "Country=Japan", "offsetgroup": "Country=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Japan"], "xaxis": "x", "y": [6.934203620032142], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Germany", "marker": {"color": "#ab63fa"}, "name": "Country=Germany", "offsetgroup": "Country=Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Germany"], "xaxis": "x", "y": [6.150016865853354], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United Kingdom", "marker": {"color": "#FFA15A"}, "name": "Country=United Kingdom", "offsetgroup": "Country=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [4.12587623453035], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Canada", "marker": {"color": "#19d3f3"}, "name": "Country=Canada", "offsetgroup": "Country=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Canada"], "xaxis": "x", "y": [3.308395819113177], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Brazil", "marker": {"color": "#FF6692"}, "name": "Country=Brazil", "offsetgroup": "Country=Brazil", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Brazil"], "xaxis": "x", "y": [3.304964277343408], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=France", "marker": {"color": "#B6E880"}, "name": "Country=France", "offsetgroup": "Country=France", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["France"], "xaxis": "x", "y": [2.928433482938946], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Italy", "marker": {"color": "#FF97FF"}, "name": "Country=Italy", "offsetgroup": "Country=Italy", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Italy"], "xaxis": "x", "y": [2.738516567975845], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Mexico", "marker": {"color": "#FECB52"}, "name": "Country=Mexico", "offsetgroup": "Country=Mexico", "orientation": "v", " ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c3c86f93-a211-49e8-ab34-a380e57289a8" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c3c86f93-a211-49e8-ab34-a380e57289a8")) {
#                     Plotly.newPlot(
#                         'c3c86f93-a211-49e8-ab34-a380e57289a8',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United States", "marker": {"color": "#636efa"}, "name": "Country=United States", "offsetgroup": "Country=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [27.618616124144708], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=China (People's Republic of)", "marker": {"color": "#EF553B"}, "name": "Country=China (People's Republic of)", "offsetgroup": "Country=China (People's Republic of)", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["China (People's Republic of)"], "xaxis": "x", "y": [16.76193301358763], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Russia", "marker": {"color": "#00cc96"}, "name": "Country=Russia", "offsetgroup": "Country=Russia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Russia"], "xaxis": "x", "y": [8.828839320564258], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Japan", "marker": {"color": "#ab63fa"}, "name": "Country=Japan", "offsetgroup": "Country=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Japan"], "xaxis": "x", "y": [5.591036454115385], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=India", "marker": {"color": "#FFA15A"}, "name": "Country=India", "offsetgroup": "Country=India", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["India"], "xaxis": "x", "y": [5.016033705961591], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Germany", "marker": {"color": "#19d3f3"}, "name": "Country=Germany", "offsetgroup": "Country=Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Germany"], "xaxis": "x", "y": [4.644333272418583], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United Kingdom", "marker": {"color": "#FF6692"}, "name": "Country=United Kingdom", "offsetgroup": "Country=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [3.131989129624473], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Canada", "marker": {"color": "#B6E880"}, "name": "Country=Canada", "offsetgroup": "Country=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Canada"], "xaxis": "x", "y": [2.628849385753865], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Brazil", "marker": {"color": "#FF97FF"}, "name": "Country=Brazil", "offsetgroup": "Country=Brazil", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Brazil"], "xaxis": "x", "y": [2.615344325311488], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=France", "marker": {"color": "# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5f658a67-9275-481a-b95f-cec89356007d" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5f658a67-9275-481a-b95f-cec89356007d")) {
#                     Plotly.newPlot(
#                         '5f658a67-9275-481a-b95f-cec89356007d',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United States", "marker": {"color": "#636efa"}, "name": "Country=United States", "offsetgroup": "Country=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [36.11862993138218], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Russia", "marker": {"color": "#EF553B"}, "name": "Country=Russia", "offsetgroup": "Country=Russia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Russia"], "xaxis": "x", "y": [11.121953016359502], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Japan", "marker": {"color": "#00cc96"}, "name": "Country=Japan", "offsetgroup": "Country=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Japan"], "xaxis": "x", "y": [7.332022804457159], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Germany", "marker": {"color": "#ab63fa"}, "name": "Country=Germany", "offsetgroup": "Country=Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Germany"], "xaxis": "x", "y": [5.981725443781736], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United Kingdom", "marker": {"color": "#FFA15A"}, "name": "Country=United Kingdom", "offsetgroup": "Country=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [4.009745461515985], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Brazil", "marker": {"color": "#19d3f3"}, "name": "Country=Brazil", "offsetgroup": "Country=Brazil", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Brazil"], "xaxis": "x", "y": [3.5211942180482962], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Canada", "marker": {"color": "#FF6692"}, "name": "Country=Canada", "offsetgroup": "Country=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Canada"], "xaxis": "x", "y": [3.483607272063964], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=France", "marker": {"color": "#B6E880"}, "name": "Country=France", "offsetgroup": "Country=France", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["France"], "xaxis": "x", "y": [2.916085139086752], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Italy", "marker": {"color": "#FF97FF"}, "name": "Country=Italy", "offsetgroup": "Country=Italy", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Italy"], "xaxis": "x", "y": [2.8241677643542453], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Mexico", "marker": {"color": "#FECB52"}, "name": "Country=Mexico", "offsetgroup": "Country=Mexico", "orientation": "v ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1e18bdbd-5cb7-44c3-b8cb-4c286a6f2c4e" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1e18bdbd-5cb7-44c3-b8cb-4c286a6f2c4e")) {
#                     Plotly.newPlot(
#                         '1e18bdbd-5cb7-44c3-b8cb-4c286a6f2c4e',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United States", "marker": {"color": "#636efa"}, "name": "Country=United States", "offsetgroup": "Country=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [36.304935429468756], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Russia", "marker": {"color": "#EF553B"}, "name": "Country=Russia", "offsetgroup": "Country=Russia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Russia"], "xaxis": "x", "y": [10.56676072548243], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Japan", "marker": {"color": "#00cc96"}, "name": "Country=Japan", "offsetgroup": "Country=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Japan"], "xaxis": "x", "y": [7.219802140149681], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Germany", "marker": {"color": "#ab63fa"}, "name": "Country=Germany", "offsetgroup": "Country=Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Germany"], "xaxis": "x", "y": [5.930621540957352], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United Kingdom", "marker": {"color": "#FFA15A"}, "name": "Country=United Kingdom", "offsetgroup": "Country=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [4.027092057005286], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Canada", "marker": {"color": "#19d3f3"}, "name": "Country=Canada", "offsetgroup": "Country=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Canada"], "xaxis": "x", "y": [3.5114683592017686], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Brazil", "marker": {"color": "#FF6692"}, "name": "Country=Brazil", "offsetgroup": "Country=Brazil", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Brazil"], "xaxis": "x", "y": [3.4599032378199195], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=France", "marker": {"color": "#B6E880"}, "name": "Country=France", "offsetgroup": "Country=France", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["France"], "xaxis": "x", "y": [2.9370969907969897], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Italy", "marker": {"color": "#FF97FF"}, "name": "Country=Italy", "offsetgroup": "Country=Italy", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Italy"], "xaxis": "x", "y": [2.7252526958625025], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Mexico", "marker": {"color": "#FECB52"}, "name": "Country=Mexico", "offsetgroup": "Country=Mexico", "orientation":  ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fb837f39-66ac-4aa9-976f-df6195cb4604" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fb837f39-66ac-4aa9-976f-df6195cb4604")) {
#                     Plotly.newPlot(
#                         'fb837f39-66ac-4aa9-976f-df6195cb4604',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United States", "marker": {"color": "#636efa"}, "name": "Country=United States", "offsetgroup": "Country=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [36.75103273136422], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Russia", "marker": {"color": "#EF553B"}, "name": "Country=Russia", "offsetgroup": "Country=Russia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Russia"], "xaxis": "x", "y": [10.0010818708842], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Japan", "marker": {"color": "#00cc96"}, "name": "Country=Japan", "offsetgroup": "Country=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Japan"], "xaxis": "x", "y": [7.211860739934733], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Germany", "marker": {"color": "#ab63fa"}, "name": "Country=Germany", "offsetgroup": "Country=Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Germany"], "xaxis": "x", "y": [5.773456164693346], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United Kingdom", "marker": {"color": "#FFA15A"}, "name": "Country=United Kingdom", "offsetgroup": "Country=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [3.9131935193571112], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Brazil", "marker": {"color": "#19d3f3"}, "name": "Country=Brazil", "offsetgroup": "Country=Brazil", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Brazil"], "xaxis": "x", "y": [3.60691307827738], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Canada", "marker": {"color": "#FF6692"}, "name": "Country=Canada", "offsetgroup": "Country=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Canada"], "xaxis": "x", "y": [3.5874408789274477], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=France", "marker": {"color": "#B6E880"}, "name": "Country=France", "offsetgroup": "Country=France", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["France"], "xaxis": "x", "y": [2.9124887756852598], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Italy", "marker": {"color": "#FF97FF"}, "name": "Country=Italy", "offsetgroup": "Country=Italy", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Italy"], "xaxis": "x", "y": [2.777765025725325], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Mexico", "marker": {"color": "#FECB52"}, "name": "Country=Mexico", "offsetgroup": "Country=Mexico", "orientation": "v", ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="71df1cfe-2789-4903-8829-1f1d867ff0b5" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("71df1cfe-2789-4903-8829-1f1d867ff0b5")) {
#                     Plotly.newPlot(
#                         '71df1cfe-2789-4903-8829-1f1d867ff0b5',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United States", "marker": {"color": "#636efa"}, "name": "Country=United States", "offsetgroup": "Country=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [37.10381907585335], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Russia", "marker": {"color": "#EF553B"}, "name": "Country=Russia", "offsetgroup": "Country=Russia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Russia"], "xaxis": "x", "y": [9.852176389322684], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Japan", "marker": {"color": "#00cc96"}, "name": "Country=Japan", "offsetgroup": "Country=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Japan"], "xaxis": "x", "y": [6.9763720090064405], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Germany", "marker": {"color": "#ab63fa"}, "name": "Country=Germany", "offsetgroup": "Country=Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Germany"], "xaxis": "x", "y": [5.655990884338787], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United Kingdom", "marker": {"color": "#FFA15A"}, "name": "Country=United Kingdom", "offsetgroup": "Country=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [3.9166914146068286], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Brazil", "marker": {"color": "#19d3f3"}, "name": "Country=Brazil", "offsetgroup": "Country=Brazil", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Brazil"], "xaxis": "x", "y": [3.7217012028387515], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Canada", "marker": {"color": "#FF6692"}, "name": "Country=Canada", "offsetgroup": "Country=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Canada"], "xaxis": "x", "y": [3.633236212865351], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=France", "marker": {"color": "#B6E880"}, "name": "Country=France", "offsetgroup": "Country=France", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["France"], "xaxis": "x", "y": [2.9918274874540383], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Mexico", "marker": {"color": "#FF97FF"}, "name": "Country=Mexico", "offsetgroup": "Country=Mexico", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Mexico"], "xaxis": "x", "y": [2.851022206942901], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Italy", "marker": {"color": "#FECB52"}, "name": "Country=Italy", "offsetgroup": "Country=Italy", "orientation":  ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1b1ed6b7-ca67-4eed-a63d-2c6a8f7aa5fd" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1b1ed6b7-ca67-4eed-a63d-2c6a8f7aa5fd")) {
#                     Plotly.newPlot(
#                         '1b1ed6b7-ca67-4eed-a63d-2c6a8f7aa5fd',
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ecef2bf4-4a04-47a4-b9dc-1d45818fd3de" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ecef2bf4-4a04-47a4-b9dc-1d45818fd3de")) {
#                     Plotly.newPlot(
#                         'ecef2bf4-4a04-47a4-b9dc-1d45818fd3de',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United States", "marker": {"color": "#636efa"}, "name": "Country=United States", "offsetgroup": "Country=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [36.76940999126671], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Russia", "marker": {"color": "#EF553B"}, "name": "Country=Russia", "offsetgroup": "Country=Russia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Russia"], "xaxis": "x", "y": [11.82501003886919], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Japan", "marker": {"color": "#00cc96"}, "name": "Country=Japan", "offsetgroup": "Country=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Japan"], "xaxis": "x", "y": [7.342756601325481], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Germany", "marker": {"color": "#ab63fa"}, "name": "Country=Germany", "offsetgroup": "Country=Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Germany"], "xaxis": "x", "y": [5.123376883089384], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Indonesia", "marker": {"color": "#FFA15A"}, "name": "Country=Indonesia", "offsetgroup": "Country=Indonesia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Indonesia"], "xaxis": "x", "y": [4.977808854251676], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Canada", "marker": {"color": "#19d3f3"}, "name": "Country=Canada", "offsetgroup": "Country=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Canada"], "xaxis": "x", "y": [3.9800897195388516], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Korea", "marker": {"color": "#FF6692"}, "name": "Country=Korea", "offsetgroup": "Country=Korea", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Korea"], "xaxis": "x", "y": [3.911723277713291], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Australia", "marker": {"color": "#B6E880"}, "name": "Country=Australia", "offsetgroup": "Country=Australia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Australia"], "xaxis": "x", "y": [3.093363451679209], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Turkey", "marker": {"color": "#FF97FF"}, "name": "Country=Turkey", "offsetgroup": "Country=Turkey", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Turkey"], "xaxis": "x", "y": [2.8052498766347123], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United Kingdom", "marker": {"color": "#FECB52"}, "name": "Country=United Kingdom", "offsetgroup": "Country=United Kingdom", "o ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="60d09537-51d7-4c3e-a570-ccec3fd1395b" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("60d09537-51d7-4c3e-a570-ccec3fd1395b")) {
#                     Plotly.newPlot(
#                         '60d09537-51d7-4c3e-a570-ccec3fd1395b',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United States", "marker": {"color": "#636efa"}, "name": "Country=United States", "offsetgroup": "Country=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [40.46930325443468], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Russia", "marker": {"color": "#EF553B"}, "name": "Country=Russia", "offsetgroup": "Country=Russia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Russia"], "xaxis": "x", "y": [13.443148195092478], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Japan", "marker": {"color": "#00cc96"}, "name": "Country=Japan", "offsetgroup": "Country=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Japan"], "xaxis": "x", "y": [8.041420898517744], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Germany", "marker": {"color": "#ab63fa"}, "name": "Country=Germany", "offsetgroup": "Country=Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Germany"], "xaxis": "x", "y": [5.578026893639519], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Canada", "marker": {"color": "#FFA15A"}, "name": "Country=Canada", "offsetgroup": "Country=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Canada"], "xaxis": "x", "y": [4.452449160143955], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Australia", "marker": {"color": "#19d3f3"}, "name": "Country=Australia", "offsetgroup": "Country=Australia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Australia"], "xaxis": "x", "y": [3.47177804090987], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Turkey", "marker": {"color": "#FF6692"}, "name": "Country=Turkey", "offsetgroup": "Country=Turkey", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Turkey"], "xaxis": "x", "y": [3.2668227473862452], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United Kingdom", "marker": {"color": "#B6E880"}, "name": "Country=United Kingdom", "offsetgroup": "Country=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [2.964355116851378], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=France", "marker": {"color": "#FF97FF"}, "name": "Country=France", "offsetgroup": "Country=France", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["France"], "xaxis": "x", "y": [2.935248155328368], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Italy", "marker": {"color": "#FECB52"}, "name": "Country=Italy", "offsetgroup": "Country=Italy", "orien ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="64f3fe7b-e1a1-4d1d-a82a-5bba57543267" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("64f3fe7b-e1a1-4d1d-a82a-5bba57543267")) {
#                     Plotly.newPlot(
#                         '64f3fe7b-e1a1-4d1d-a82a-5bba57543267',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United States", "marker": {"color": "#636efa"}, "name": "Country=United States", "offsetgroup": "Country=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [41.330905352074296], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Russia", "marker": {"color": "#EF553B"}, "name": "Country=Russia", "offsetgroup": "Country=Russia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Russia"], "xaxis": "x", "y": [13.74337384568379], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Japan", "marker": {"color": "#00cc96"}, "name": "Country=Japan", "offsetgroup": "Country=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Japan"], "xaxis": "x", "y": [7.665794713882046], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Germany", "marker": {"color": "#ab63fa"}, "name": "Country=Germany", "offsetgroup": "Country=Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Germany"], "xaxis": "x", "y": [5.3136163591095995], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Canada", "marker": {"color": "#FFA15A"}, "name": "Country=Canada", "offsetgroup": "Country=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Canada"], "xaxis": "x", "y": [4.514938985298931], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Australia", "marker": {"color": "#19d3f3"}, "name": "Country=Australia", "offsetgroup": "Country=Australia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Australia"], "xaxis": "x", "y": [3.454516584647695], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Turkey", "marker": {"color": "#FF6692"}, "name": "Country=Turkey", "offsetgroup": "Country=Turkey", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Turkey"], "xaxis": "x", "y": [3.224819138743683], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=United Kingdom", "marker": {"color": "#B6E880"}, "name": "Country=United Kingdom", "offsetgroup": "Country=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [2.88428887702997], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=France", "marker": {"color": "#FF97FF"}, "name": "Country=France", "offsetgroup": "Country=France", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["France"], "xaxis": "x", "y": [2.7993434912484525], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>Greenhouse gases emission(%)=%{y}", "legendgroup": "Country=Italy", "marker": {"color": "#FECB52"}, "name": "Country=Italy", "offsetgroup": "Country=Italy", "orie ...

# %%
year_sums[year_sums["Country"]=="United States"]
# Out:
#       Year        Country  Greenhouse gases emission(%)
# 39    1990  United States                     32.833248
# 78    1991  United States                     33.398641
# 117   1992  United States                     34.767265
# 156   1993  United States                     35.484585
# 198   1994  United States                     27.618616
# 237   1995  United States                     36.118630
# 277   1996  United States                     36.304935
# 316   1997  United States                     36.751033
# 355   1998  United States                     37.103819
# 394   1999  United States                     37.207442
# 436   2000  United States                     33.748950
# 476   2001  United States                     35.935115
# 516   2002  United States                     35.992931
# 557   2003  United States                     35.587515
# 598   2004  United States                     35.737792
# 641   2005  United States                     26.196297
# 682   2006  United States                     35.170124
# 723   2007  United States                     35.300203
# 764   2008  United States                     34.754026
# 805   2009  United States                     34.353787
# 848   2010  United States                     31.120234
# 889   2011  United States                     33.646120
# 932   2012  United States                     20.517583
# 972   2013  United States                     35.137847
# 1012  2014  United States                     35.613645
# 1050  2015  United States                     35.833725
# 1087  2016  United States                     36.769410
# 1120  2017  United States                     40.469303
# 1153  2018  United States                     41.330905
